# %% [markdown]
# # Get tf-idf_SVD, euclidean-distance and cosine-distance matrices
# The overall goal for this script is to iterate through **neuroscience-related R01s** for **each year**, get the abstracts for each of those projects and return three matrices and one dataframe:
# 1. **tf-idf_SVD**: This is a SVD-decomposed tf-idf wordcount matrix [n_abstracts, n_components]. I will use this for k-means clustering and affinity propagation (I think).
# 2. **cos_SVD**: This is a cosine distance matrix [n_abstracts, n_abstracts] generated from tf-idf_SVD. I will use this for Ward hierarchical clustering.
# 3. **euc_SVD**: This is an euclidean distance matrix [n_abstracts, n_abstracts] generated from tf-idf_SVD. I will also use this for Ward hierarchical clustering.
# 4. **df_neuro**: This is a dataframe, filtered for neuro-related R01s, containing information about each project.

# %%
import os
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot

from string import punctuation
from nltk.corpus import stopwords
from nltk import PorterStemmer

# %matplotlib inline

# %% [markdown]
# # Read abstracts and project csvs into dataframes

# %%
initialize_df = pd.DataFrame(columns=['wordlist', 'year'])

# %%
try: 
    initialize_df.to_csv('all_years.csv')
except: 
    pass

# %%
def get_abstracts_projects(year):
    """
    input: int -- year to analyze; [1985:2016] inclusive.
    returns: 2 dataframes -- project & abstract
    """
    abs_dir = './abstracts/'
    proj_dir = './projects/'
    
    project = pd.read_csv(proj_dir + 'RePORTER_PRJ_C_FY' + year + '.csv', encoding = "ISO-8859-1")
    abstract = pd.read_csv(abs_dir + 'RePORTER_PRJABS_C_FY' + year + '.csv',encoding = "ISO-8859-1")
    
    return project, abstract

# %% [markdown]
# # Clean and filter for neuro abstracts

# %% [markdown]
# ### Clean abstracts (stemming, lowercase, no punctuation, remove stopwords)

# %%
# get customized stopwords:
def customized_stopwords(to_append=[]):
    """
    to_append: list; what words do you want to exclude from your analysis, in addition to the standard 
    stopwords like 'the', 'and, 'of', and so on? See above to_append variable for examples.
    returns: list; stopwords including to_append list
    """
    stop = stopwords.words('english')
    stop = stop + to_append
    return stop

# get list of words that are lowercase, with punctuation removed and words stemmed.
def get_wordlist(abstract, stop = customized_stopwords()):
    """
    returns a list of lowercase words from abstract with punctuation and stopwords removed.
    """
    try:
        # make words lowercase
        words = abstract.lower()
        
        # take out all punctuation and split strings into a list of words
        words = (''.join(c for c in words if c not in punctuation)).split(' ')
        
        # remove stopwords
        words = [" ".join([w for w in word.split() if not w in stop]) for word in words]
        
        # stem words using Porter's Stemmer
        stemmed = []
        for word in words:
            try:
                word = PorterStemmer().stem(word)
            except IndexError:
                word = word
            if word != '' and word.isalpha():
                stemmed.append(word)
        words = stemmed

    except AttributeError:
        words = []
    return words

# %% [markdown]
# ### Filter for neuro-related abstracts.
# I defined a project to be neuroscience-related if the abstract mentioned "brain" or "neur*" at least once every 100 non-stopwords.

# %%
def neuro_count(row):
    try:
        return (row.ABSTRACT_TEXT.count(' brain') + row.ABSTRACT_TEXT.count('neur'))
    except AttributeError:
        return 0
    
def wordlist_count(row):
    return len(row.wordlist)
    
def neuro_only(df, word_density=0.01):
    """
    input: dataframe
    word_density: how many neuro related words for every 100 words that are not stopwords in an abstract? Stopwords: the, and, or, not, etc.
    returns: dataframe containing neuro-related projects as defined above, with a column containing cleaned abstract keywords for analysis.
    """
    df['abs_neuro_count'] = df.apply(neuro_count, axis=1)
    df['wordlist'] = df.ABSTRACT_TEXT.apply(get_wordlist)
    df['wordlist_ct'] = df.apply(wordlist_count, axis=1)
    df['rel_neuro_count'] = df.abs_neuro_count / df.wordlist_ct
    
    # drop duplicates - I found that in some years, there are duplicate abstracts which really screwed up my hierarchical clustering
    df = df.drop_duplicates('ABSTRACT_TEXT')
    return df[df.rel_neuro_count >= word_density]

# %% [raw]
# # Implement clean abstracts and filter for neuro projects.
# df_neuro = neuro_only(df)
#
# # look only at R01s
# df_neuro_granttype = df_neuro[df_neuro.ACTIVITY == grant_type]

# %% [raw]
# ### Save and write wordlist (neuro R01s), with year, to all_years.csv

# %% [raw]
# df_to_save = pd.DataFrame(df_neuro_granttype['wordlist'])
# df_to_save['year'] = year

# %% [raw]
# df_to_save.to_csv('all_years.csv', mode='a')

# %% [markdown]
# # Implementation

# %%
# years = range(1985,2017)
years = [1996]
grant_type = 'R01'

# get abstracts and projects for a single year
for year in years:
    project, abstract = get_abstracts_projects(str(year))

    # join abstracts to projects dataframe
    df = project.merge(abstract, on='APPLICATION_ID', how='left')
    
    # Implement clean abstracts and filter for neuro projects.
    df_neuro = neuro_only(df)

    # look only at R01s
    df_neuro_granttype = df_neuro[df_neuro.ACTIVITY == grant_type]

    df_to_save = pd.DataFrame(df_neuro_granttype['wordlist'])
    df_to_save['year'] = year

#     df_to_save.to_csv('all_years.csv', mode='a', header=False)
    
    print (year, 'done')
    
print ('all done')
# Out:
# //anaconda/lib/python3.5/site-packages/IPython/core/interactiveshell.py:2825: DtypeWarning: Columns (21) have mixed types. Specify dtype option on import or set low_memory=False.
#   if self.run_code(code, result):
# 1996 done
# all done

# %%
project.shape
# Out:
# (65224, 42)

# %%
project[project.ACTIVITY=='R01']
# Out:
#        APPLICATION_ID ACTIVITY ADMINISTERING_IC  APPLICATION_TYPE  \
# 29770         2042885      R01               AA                 5
# 29771         2042892      R01               AA                 5
# 29772         2042949      R01               AA                 5
# 29773         2042954      R01               AA                 5
# 29774         2042961      R01               AA                 5
# 29775         2042966      R01               AA                 5
# 29776         2043006      R01               AA                 5
# 29777         2043012      R01               AA                 5
# 29778         2043040      R01               AA                 5
# 29779         2043041      R01               AA                 3
# 29780         2043045      R01               AA                 3
# 29781         2043047      R01               AA                 2
# 29782         2043052      R01               AA                 2
# ...

# %%
abstract.shape
# Out:
# (26602, 2)

# %%
df.head()
# Out:
#    APPLICATION_ID ACTIVITY ADMINISTERING_IC  APPLICATION_TYPE  ARRA_FUNDED  \
# 0         2056405      A03               AH                 1          NaN
# 1         2056406      A03               AH                 1          NaN
# 2         2056407      A03               AH                 1          NaN
# 3         2056408      A03               AH                 1          NaN
# 4         2056409      A03               AH                 1          NaN
#
#      AWARD_NOTICE_DATE BUDGET_START  BUDGET_END  CFDA_CODE CORE_PROJECT_NUM  \
# 0  1996-04-24T00:00:00   07/01/1996  06/30/1997        NaN      A03AH001151
# 1  1996-04-24T00:00:00   07/01/1996  06/30/1997        NaN      A03AH001152
# 2  1996-04-24T00:00:00   07/01/1996  06/30/1997        NaN      A03AH001153
# 3  1996-04-24T00:00:00   07/01/1996  06/30/1997        NaN      A03AH001154
# 4  1996-04-24T00:00:00   07/01/1996  06/30/1997        NaN      A03AH001155
#
# ...

# %%
df.shape
# Out:
# (65224, 47)

# %%
df.ABSTRACT_TEXT.dropna().shape
# Out:
# (22124,)

# %%
df[df.ACTIVITY=='R01']
# Out:
#        APPLICATION_ID ACTIVITY ADMINISTERING_IC  APPLICATION_TYPE  \
# 29770         2042885      R01               AA                 5
# 29771         2042892      R01               AA                 5
# 29772         2042949      R01               AA                 5
# 29773         2042954      R01               AA                 5
# 29774         2042961      R01               AA                 5
# 29775         2042966      R01               AA                 5
# 29776         2043006      R01               AA                 5
# 29777         2043012      R01               AA                 5
# 29778         2043040      R01               AA                 5
# 29779         2043041      R01               AA                 3
# 29780         2043045      R01               AA                 3
# 29781         2043047      R01               AA                 2
# 29782         2043052      R01               AA                 2
# ...

# %%
df[df.ACTIVITY=='R01'].ABSTRACT_TEXT.dropna().shape
# Out:
# (1068,)

# %% [raw]
# # Topic extraction using abstract words
# [This](http://alexperrier.github.io/jekyll/update/2015/09/04/topic-modeling-of-twitter-followers.html) was an incredibly helpful resource.

# %% [raw]
# from gensim import corpora, models
# import pyLDAvis.gensim

# %% [raw]
# text = list(df_neuro_granttype.wordlist)
#
# # get unique words list
# dictionary = corpora.Dictionary(text)
#
# # get document-term matrix
# corpus = [dictionary.doc2bow(tex) for tex in text]

# %% [raw]
# ## Let's just initialize and start with a reasonable number of topics (n=10) and value for alpha (0.01).

# %% [raw]
# lda = models.ldamodel.LdaModel(corpus, num_topics=10, passes=10, alpha=0.01)
# followers_data =  pyLDAvis.gensim.prepare(lda, corpus, dictionary)
# pyLDAvis.display(followers_data)

# %% [raw]
# For the first pass, I am actually quite impressed -- the topics seemed to be pretty well separated out. I think the number of topics needs to get larger because it seemed like a few topics were merged (e.g., alcohol, stress in topic 4). But before I vary the number of topics, let's vary alpha to see what happens.

# %% [raw]
# ## Try different values of alpha

# %% [raw]
# Here, I made alpha larger (more topics per abstract). Intuitively I knew this was not going to get good clusters because each abstract doesn't contain that many topics. But, I wanted to see what manipulating alpha did.

# %% [raw]
# lda = models.ldamodel.LdaModel(corpus, num_topics=10, passes=10, alpha=0.1)
# followers_data =  pyLDAvis.gensim.prepare(lda, corpus, dictionary)
# pyLDAvis.display(followers_data)

# %% [raw]
# As expected, this model with a larger alpha gave results that were a bit odd. They weren't terrible, but not as good as the first model.

# %% [raw]
# lda = models.ldamodel.LdaModel(corpus, num_topics=10, passes=10, alpha=0.001)
# followers_data =  pyLDAvis.gensim.prepare(lda, corpus, dictionary)
# pyLDAvis.display(followers_data)

# %% [raw]
# This one just gave weird results. For example, Topic 10 -- why does it have auditory, obesity, and hypothalamus stuff all together? Doesn't make sense.

# %% [raw]
# ## Try more topics

# %% [raw]
# lda = models.ldamodel.LdaModel(corpus, num_topics=50, passes=50, alpha=0.01)
# followers_data =  pyLDAvis.gensim.prepare(lda, corpus, dictionary)
# pyLDAvis.display(followers_data)

# %% [raw]
# 50 was way too many topics, and not all of them made sense. There were many of those topics where I wouldn't necessarily classify as the top 50 topics in neuroscience. I think I need to go down in number of topics. I'll try 20 this time, with the same alpha (0.01). Without looking at the results, I would expect that the actual number of topics for 2016 in neuroscience would be around 15-20 (major topics). I'd also expect each abstract to contain about 2-3 topics.

# %% [raw]
# lda = models.ldamodel.LdaModel(corpus, num_topics=20, passes=20, alpha=0.01)
# followers_data =  pyLDAvis.gensim.prepare(lda, corpus, dictionary)
# pyLDAvis.display(followers_data)

# %% [raw]
# Trying 20 topics also made things separate out in weird ways (olfaction and stress in Topic 14). I will decrease to 15 topics.

# %% [raw]
# lda = models.ldamodel.LdaModel(corpus, num_topics=15, passes=15, alpha=0.01)
# followers_data =  pyLDAvis.gensim.prepare(lda, corpus, dictionary)
# pyLDAvis.display(followers_data)

# %% [raw]
# lda = models.ldamodel.LdaModel(corpus, num_topics=12, passes=15, alpha=0.01)
# followers_data =  pyLDAvis.gensim.prepare(lda, corpus, dictionary)
# pyLDAvis.display(followers_data)

# %% [raw]
# lda = models.ldamodel.LdaModel(corpus, num_topics=8, passes=15, alpha=0.01)
# followers_data =  pyLDAvis.gensim.prepare(lda, corpus, dictionary)
# pyLDAvis.display(followers_data)

# %% [raw]
# While I thought with 8 topics, the topics separated out pretty well, I felt 2 and 4 needed to be split apart - topic 4 encompasses synapse/electrophysiology with random molecular neurobiology fields, and Topic 2 combined systems with a bit of molecular neurobiology. I think 10 topics is my favorite. Let me go ahead and do 100 passes to ensure proper convergence and save that model. Curiously, neurodegenerative diseases consistently separates out *very* well.

# %% [raw]
# # Implement LDA

# %% [raw]
# lda = models.ldamodel.LdaModel(corpus, num_topics=12, passes=10, alpha=0.01)
# followers_data =  pyLDAvis.gensim.prepare(lda, corpus, dictionary)
# pyLDAvis.display(followers_data)

# %% [raw]
# lda = models.ldamodel.LdaModel(corpus, num_topics=10, passes=10, alpha=0.01)
# followers_data =  pyLDAvis.gensim.prepare(lda, corpus, dictionary)
# pyLDAvis.display(followers_data)

# %% [raw]
# lda = models.ldamodel.LdaModel(corpus, num_topics=8, passes=10, alpha=0.01)
# followers_data =  pyLDAvis.gensim.prepare(lda, corpus, dictionary)
# pyLDAvis.display(followers_data)

# %% [raw]
# lda = models.ldamodel.LdaModel(corpus, num_topics=10, passes=10, alpha=0.1)
# followers_data =  pyLDAvis.gensim.prepare(lda, corpus, dictionary)
# pyLDAvis.display(followers_data)

# %% [raw]
# I will try to quantify how big each topic is in two ways. First, split up project based on topic probability. And get topic size by summing up proportions of each project inside it.

# %% [raw]
# def get_topic_size_split_project(num_topics, corpus, lda):
#
#     # initialize topic dict
#     topic_dict = {}
#     for j in range(num_topics):
#         topic_dict[j] = 0
#
#     # add project proportions into each topic
#     for i in range(len(corpus)):
#         doc_topics = lda.get_document_topics(corpus[i])
#         for topic in doc_topics:
#             topic_dict[topic[0]] += topic[1]
#
#     return topic_dict

# %% [raw]
# split_dict = get_topic_size_split_project(10, corpus, lda)

# %% [raw]
# Second, bin the entire project into a topic space based on highest probability.

# %% [raw]
# def get_topic_size_whole_project(num_topics, corpus, lda):
#     from operator import itemgetter
#     # initialize topic dict
#     topic_dict = {}
#     for j in range(num_topics):
#         topic_dict[j] = 0
#
#     # add whole projects into topic
#     for i in range(len(corpus)):
#         doc_topics = lda.get_document_topics(corpus[i])
#         np_topics = np.array(doc_topics)
#         index = np.argmax(np_topics, axis=0)[1]
#         topic_dict[doc_topics[index][0]] += 1
#
#     assert (sum(topic_dict.values()) == len(corpus)), "algo wrong"
#     return topic_dict

# %% [raw]
# whole_dict = get_topic_size_whole_project(10, corpus, lda)

# %% [raw]
# def topic_size_scatter(topic_dict):
#     td_list = [(k,v) for k,v in topic_dict.items()]
#     x_td_list = [x[0] for x in td_list]
#     y_td_list = [x[1] for x in td_list]
#     return x_td_list, y_td_list

# %% [raw]
# s_x, s_y = topic_size_scatter(split_dict)
# w_x, w_y = topic_size_scatter(whole_dict)

# %% [raw]
# ## How similar are the two ways I choose to represent topic size?
#
# Pretty similar!

# %% [raw]
# pyplot.scatter(s_x, s_y, color='b')
# pyplot.scatter(w_x, w_y, color='r')

# %% [raw]
# # How heavily funded is a topic?

# %% [raw]
# # Export things

# %% [raw]
# save_things = pd.DataFrame()
# save_things['topics'] = topic_head.values()
# save_things['s_y'] = s_y
# save_things['w_y'] = w_y
#
# df_neuro_granttype['corpus'] = corpus

# %% [raw]
# save_things

# %% [raw]
# save_things.to_csv(year + '_topics.csv')
# df_neuro_granttype.to_csv(year + '_' + grant_type + '_' + 'df.csv')

# %% [raw]
# # Get tf-idf transformation of feature vectors

# %% [raw]
# from gensim.models import tfidfmodel
# tfidf = tfidfmodel.TfidfModel(corpus)
# tfidf_corpus = tfidf[corpus]

# %% [raw]
# # Decompose tf-idf using SVD (latent semantic analysis)

# %% [raw]
# def get_svd(tfidf):
#     """
#     apply SVD to tfidf
#     """
#     from sklearn.decomposition import TruncatedSVD
#
#     svd = TruncatedSVD(n_components=len(tfidf.columns)-1)
#     svd.fit_transform(tfidf)
#
#     pyplot.figure()
#     pyplot.plot(svd.explained_variance_ratio_.cumsum())
#     pyplot.show()
#
# def recalc_svd(tfidf, components):
#     """
#     get user input for number of components that should explain >0.9 variance
#     """
#
#     from sklearn.decomposition import TruncatedSVD
#
#     svd = TruncatedSVD(n_components = components)
#     train_lsa = svd.fit_transform(tfidf)
#     return train_lsa, svd
#
# def plot_svd(svd, tfidf):
#     """
#     plots word contribution for top 10 SVD components, and variance explained
#     """
#     feat_names = list(tfidf.columns)
#
#     for compNum in range(0, 10):
#         comp = svd.components_[compNum]
#
#         # Sort the weights in the first component, and get the indices
#         indices = np.argsort(comp).tolist()
#
#         # Reverse the indices, so we have the largest weights first.
#         indices.reverse()
#
#         # Grab the top 10 terms which have the highest weight in this component.
#         terms = [feat_names[weightIndex] for weightIndex in indices[0:10]]
#         weights = [comp[weightIndex] for weightIndex in indices[0:10]]
#
#         # Display these terms and their weights as a horizontal bar graph.
#         # The horizontal bar graph displays the first item on the bottom; reverse
#         # the order of the terms so the biggest one is on top.
#         terms.reverse()
#         weights.reverse()
#         positions = np.arange(10) + .5    # the bar centers on the y axis
#
#         pyplot.figure(compNum)
#         pyplot.barh(positions, weights, align='center')
#         pyplot.yticks(positions, terms)
#         pyplot.xlabel('Weight')
#         pyplot.title('Strongest terms for component %d' % (compNum))
#         pyplot.show()

# %% [raw]
# # get tfidf SVD
# get_svd(fv_neuro_tfidf)
# components = int(input('How many components to grab?: '))
# tfidf_svd, svd = recalc_svd(fv_neuro_tfidf, components)
# plot_svd(svd, fv_neuro_tfidf)

# %% [raw]
# ### Get Euclidean similarity distance matrix

# %% [raw]
# def euc_dist_matrix(tfidf):
#     from sklearn.metrics.pairwise import euclidean_distances
#     return euclidean_distances(tfidf)

# %% [raw]
# # Putting everything together

# %% [raw]
# # get cosine distance matrix
# cos_matrix = get_cosine_matrix(tfidf_svd)
#
# # get euclidean distance matrix
# euc_dist = euc_dist_matrix(tfidf_svd)
#
# # save files:
# # save neuro R01s dataframe
# df_neuro_granttype.to_csv('./matrices/neuro_df' + year + '_' + grant_type + '.csv')
#
# # save decomposed tfidf
# np.savetxt('./matrices/tfidfsvd_' + year + '_' + grant_type + '.csv', tfidf_svd, delimiter = ',')
#
# # save cosine distance matrix (using decomposed tfidf)
# np.savetxt('./matrices/cos_' + year + '_' + grant_type + '.csv', cos_matrix, delimiter = ',')
#
# # save euclidean distance matrix (using decomposed tfidf)
# np.savetxt('./matrices/euc_' + year + '_' + grant_type + '.csv', euc_dist, delimiter = ',')
